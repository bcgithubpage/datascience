# %% [markdown]
# ## import and merge multiple text files

# %%
import numpy as np
import pandas as pd

# %%
#import files by year names
pd.read_csv("names\yob1990.txt")
# Out:
#         Jessica  F  46481
# 0        Ashley  F  45561
# 1      Brittany  F  36538
# 2        Amanda  F  34410
# 3      Samantha  F  25865
# 4         Sarah  F  25818
# ...         ... ..    ...
# 24710      Zeus  M      5
# 24711     Ziyad  M      5
# 24712     Zoilo  M      5
# 24713     Zoran  M      5
# 24714       Zvi  M      5
#
# [24715 rows x 3 columns]

# %%
# of files 
# create a list - yob from 1895 to 2019

years = list(range(1895,2020))
years
# Out:
# [1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
# ...

# %%
#header = 0
#names = ['Name','Gender','Count']

yob_years=[]
for i in years:
    data = pd.read_csv("names\yob{}.txt".format(i), header=None, names=['Name','Gender','Count'])
    yob_years.append(data)

# %%
yob_years
# Out:
# [           Name Gender  Count
#  0          Mary      F  13446
#  1          Anna      F   5950
#  2         Helen      F   4023
#  3      Margaret      F   3931
#  4     Elizabeth      F   3603
#  ...         ...    ...    ...
#  3044       Whit      M      5
#  3045    Wilfrid      M      5
#  3046    Wilhelm      M      5
#  3047       Wong      M      5
#  3048        Yee      M      5
#
#  [3049 rows x 3 columns],
#            Name Gender  Count
#  0         Mary      F  13811
#  1         Anna      F   5860
#  2        Helen      F   4392
#  3     Margaret      F   4050
#  4         Ruth      F   3905
#  ...        ...    ...    ...
#  3086    Worley      M      5
#  3087    Wright      M      5
#  3088    Xavier      M      5
#  3089      York      M      5
#  3090    Zollie      M      5
#
#  [3091 rows x 3 columns],
#            Name Gender  Count
#  0         Mary      F  13413
#  1         Anna      F   5429
#  2        Helen      F   4519
#  3     Margaret      F   4146
# ...

# %%
#combine all of the data from years 1895 to 2019

pd.concat(yob_years, keys=years, names=['Year'])
# Out:
#                  Name Gender  Count
# Year
# 1895 0           Mary      F  13446
#      1           Anna      F   5950
#      2          Helen      F   4023
#      3       Margaret      F   3931
#      4      Elizabeth      F   3603
# ...               ...    ...    ...
# 2019 31949     Zyheem      M      5
#      31950      Zykel      M      5
#      31951     Zyking      M      5
#      31952        Zyn      M      5
#      31953      Zyran      M      5
#
# [1952610 rows x 3 columns]

# %%
pd.concat(yob_years, keys=years, names=['Year']).droplevel(-1)
# Out:
#            Name Gender  Count
# Year
# 1895       Mary      F  13446
# 1895       Anna      F   5950
# 1895      Helen      F   4023
# 1895   Margaret      F   3931
# 1895  Elizabeth      F   3603
# ...         ...    ...    ...
# 2019     Zyheem      M      5
# 2019      Zykel      M      5
# 2019     Zyking      M      5
# 2019        Zyn      M      5
# 2019      Zyran      M      5
#
# [1952610 rows x 3 columns]

# %%
df = pd.concat(yob_years, keys=years, names=['Year']).droplevel(-1).reset_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952610 entries, 0 to 1952609
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Year    int64
#  1   Name    object
#  2   Gender  object
#  3   Count   int64
# dtypes: int64(2), object(2)
# memory usage: 59.6+ MB

# %%
#save combined data 
df.to_csv("us_baby_names.csv", index=False)

# %% [markdown]
# ## utilize glob module

# %%
from glob import glob #all file /path names by specificying pattern

# %%
pd.read_csv("namestates/AK.TXT", header=None, names=['State','Gender','Year','Name','Count'])
# Out:
#       State Gender  Year      Name  Count
# 0        AK      F  1910      Mary     14
# 1        AK      F  1910     Annie     12
# 2        AK      F  1910      Anna     10
# 3        AK      F  1910  Margaret      8
# 4        AK      F  1910     Helen      7
# ...     ...    ...   ...       ...    ...
# 28957    AK      M  2019   Patrick      5
# 28958    AK      M  2019     Ronin      5
# 28959    AK      M  2019  Sterling      5
# 28960    AK      M  2019     Titus      5
# 28961    AK      M  2019    Tucker      5
#
# [28962 rows x 5 columns]

# %%
glob("namestates\\*.TXT")
# Out:
# ['namestates\\AK.TXT',
#  'namestates\\AL.TXT',
#  'namestates\\AR.TXT',
#  'namestates\\AZ.TXT',
#  'namestates\\CA.TXT',
#  'namestates\\CO.TXT',
#  'namestates\\CT.TXT',
#  'namestates\\DC.TXT',
#  'namestates\\DE.TXT',
#  'namestates\\FL.TXT',
#  'namestates\\GA.TXT',
#  'namestates\\HI.TXT',
#  'namestates\\IA.TXT',
#  'namestates\\ID.TXT',
#  'namestates\\IL.TXT',
#  'namestates\\IN.TXT',
#  'namestates\\KS.TXT',
#  'namestates\\KY.TXT',
#  'namestates\\LA.TXT',
#  'namestates\\MA.TXT',
#  'namestates\\MD.TXT',
#  'namestates\\ME.TXT',
#  'namestates\\MI.TXT',
#  'namestates\\MN.TXT',
#  'namestates\\MO.TXT',
#  'namestates\\MS.TXT',
#  'namestates\\MT.TXT',
#  'namestates\\NC.TXT',
#  'namestates\\ND.TXT',
#  'namestates\\NE.TXT',
#  'namestates\\NH.TXT',
#  'namestates\\NJ.TXT',
#  'namestates\\NM.TXT',
#  'namestates\\NV.TXT',
#  'namestates\\NY.TXT',
#  'namestates\\OH.TXT',
#  'namestates\\OK.TXT',
#  'namestates\\OR.TXT',
#  'namestates\\PA.TXT',
#  'namestates\\RI.TXT',
# ...

# %%
pd.read_csv('namestates\\WY.TXT')
# Out:
#        WY  F  1910      Mary  27
# 0      WY  F  1910  Margaret  22
# 1      WY  F  1910     Helen  13
# 2      WY  F  1910     Alice  10
# 3      WY  F  1910   Dorothy   9
# 4      WY  F  1910   Frances   8
# ...    .. ..   ...       ...  ..
# 28276  WY  M  2019      Theo   5
# 28277  WY  M  2019   Tristan   5
# 28278  WY  M  2019   Vincent   5
# 28279  WY  M  2019    Warren   5
# 28280  WY  M  2019    Waylon   5
#
# [28281 rows x 5 columns]

# %%
filenames = glob("namestates\\*.TXT")

# %%
len(filenames)
# Out:
# 51

# %%
file_list=[]
for i in filenames:
    df =pd.read_csv(i, header=None, names=['State','Gender','Year','Name','Count'])
    file_list.append(df)

# %%
file_list
# Out:
# [      State Gender  Year      Name  Count
#  0        AK      F  1910      Mary     14
#  1        AK      F  1910     Annie     12
#  2        AK      F  1910      Anna     10
#  3        AK      F  1910  Margaret      8
#  4        AK      F  1910     Helen      7
#  ...     ...    ...   ...       ...    ...
#  28957    AK      M  2019   Patrick      5
#  28958    AK      M  2019     Ronin      5
#  28959    AK      M  2019  Sterling      5
#  28960    AK      M  2019     Titus      5
#  28961    AK      M  2019    Tucker      5
#
#  [28962 rows x 5 columns],
#         State Gender  Year     Name  Count
#  0         AL      F  1910     Mary    875
#  1         AL      F  1910    Annie    482
#  2         AL      F  1910   Willie    257
#  3         AL      F  1910   Mattie    232
#  4         AL      F  1910     Ruby    204
#  ...      ...    ...   ...      ...    ...
#  135657    AL      M  2019    Zaire      5
#  135658    AL      M  2019   Zakari      5
# ...

# %%
df1 = pd.concat(file_list, axis=0, ignore_index=True)
df1.head()
# Out:
#   State Gender  Year      Name  Count
# 0    AK      F  1910      Mary     14
# 1    AK      F  1910     Annie     12
# 2    AK      F  1910      Anna     10
# 3    AK      F  1910  Margaret      8
# 4    AK      F  1910     Helen      7

# %%
df1.to_csv("baby_names_states.csv", index=False)

# %%
pd.read_csv("baby_names_states.csv")
# Out:
#         State Gender  Year      Name  Count
# 0          AK      F  1910      Mary     14
# 1          AK      F  1910     Annie     12
# 2          AK      F  1910      Anna     10
# 3          AK      F  1910  Margaret      8
# 4          AK      F  1910     Helen      7
# ...       ...    ...   ...       ...    ...
# 6122885    WY      M  2019      Theo      5
# 6122886    WY      M  2019   Tristan      5
# 6122887    WY      M  2019   Vincent      5
# 6122888    WY      M  2019    Warren      5
# 6122889    WY      M  2019    Waylon      5
#
# [6122890 rows x 5 columns]

# %% [markdown]
# Two files are now saved - us_baby_names.csv and baby_names_states.csv
