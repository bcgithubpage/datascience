# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Features
# * **longitude:**  geographic coordinate (district´s east-west position)
# * **latitude:**  geographic coordinate (district´s north-south position)
# * **housing_median_age:** median age of houses in district
# * **total_rooms** Sum of all rooms in district
# * **total_bedrooms** Sum of all bedrooms in district
# * **population:** total population in district
# * **households:** total households in district
# * **median_income:** median household income in district
# * **median_house_value:** median house value in district
# * **ocean_proximity:** District´s proximity to the ocean (categorical data)

# %%
df.describe(include='all')
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# ...

# %%
#total_bedrooms - have missing values

df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df[df['total_bedrooms'].isnull()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
df[df.duplicated(keep=False)] #check if duplicated rows
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
df.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.total_bedrooms.value_counts()
# Out:
# 280.0     55
# 331.0     51
# 345.0     50
# 393.0     49
# 343.0     49
#           ..
# 2205.0     1
# 1448.0     1
# 1691.0     1
# 2537.0     1
# 2546.0     1
# Name: total_bedrooms, Length: 1923, dtype: int64

# %%
df.hist(bins=50, figsize=(20,15))
plt.show() #first inspection of data

# %% [markdown]
# ## Data Cleaning + Additional Features

# %%
#either use median to replace missing value or drop 

207 / 20640
# Out:
# 0.01002906976744186

# %%
#1% missing - below the 5% threshold hence can be removed 

df.dropna(inplace=True)

# %%
#rooms per household - new feature (total_rooms / households)

df['rooms_per_household'] = df['total_rooms'] / df['households']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household
# 0             6.984127
# ...

# %%
df['rooms_per_household'].nlargest(10)
# Out:
# 1914     141.909091
# 1979     132.533333
# 12447     62.422222
# 1913      61.812500
# 11862     59.875000
# 1912      56.269231
# 9676      52.848214
# 11707     52.690476
# 2395      50.837838
# 1240      47.515152
# Name: rooms_per_household, dtype: float64

# %%
df.rooms_per_household.nsmallest(10)
# Out:
# 5916     0.846154
# 8219     0.888889
# 3126     1.000000
# 14818    1.130435
# 17820    1.130435
# 4552     1.260870
# 4550     1.378486
# 4587     1.411290
# 4602     1.465753
# 12484    1.550409
# Name: rooms_per_household, dtype: float64

# %% [markdown]
# - 2 extreme values within the 10 largest rooms_per_household (with over 20k observations, decide to keep the 2 extreme / suspicious values) - could further inspect
# - inspect 1914, 5916 and 8219

# %%
df.loc[[1914,5916, 8219]]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1914    -120.10     38.91                33.0       1561.0           282.0
# 5916    -118.44     34.28                46.0         11.0            11.0
# 8219    -118.21     33.79                33.0         32.0            18.0
#
#       population  households  median_income  median_house_value  \
# 1914        30.0        11.0         1.8750            500001.0
# 5916        24.0        13.0         2.8750            162500.0
# 8219        96.0        36.0         4.5938            112500.0
#
#      ocean_proximity  rooms_per_household
# 1914          INLAND           141.909091
# 5916       <1H OCEAN             0.846154
# 8219      NEAR OCEAN             0.888889

# %%
df['pop_per_household'] = df.population / df.households

# %%
df['bedrooms_per_room'] = df.total_bedrooms / df.total_rooms

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ## Identify features that impact home prices

# %%
df.median_house_value.hist(bins=50, figsize=(12,8))
plt.show()

# %%
#linear relationship between house prices and features
df.corr()
# Out:
#                      longitude  latitude  housing_median_age  total_rooms  \
# longitude             1.000000 -0.924616           -0.109357     0.045480
# latitude             -0.924616  1.000000            0.011899    -0.036667
# housing_median_age   -0.109357  0.011899            1.000000    -0.360628
# total_rooms           0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms        0.069608 -0.066983           -0.320451     0.930380
# population            0.100270 -0.108997           -0.295787     0.857281
# households            0.056513 -0.071774           -0.302768     0.918992
# median_income        -0.015550 -0.079626           -0.118278     0.197882
# median_house_value   -0.045398 -0.144638            0.106432     0.133294
# rooms_per_household  -0.027307  0.106423           -0.153031     0.133482
# pop_per_household     0.002304  0.002522            0.013258    -0.024596
# bedrooms_per_room     0.092657 -0.113815            0.136089    -0.187900
#
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='Blues', vmin=-1, vmax=1)
plt.show()

# %%
df.corr()['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value     1.000000
# median_income          0.688355
# rooms_per_household    0.151344
# total_rooms            0.133294
# housing_median_age     0.106432
# households             0.064894
# total_bedrooms         0.049686
# pop_per_household     -0.023639
# population            -0.025300
# longitude             -0.045398
# latitude              -0.144638
# bedrooms_per_room     -0.255880
# Name: median_house_value, dtype: float64

# %%
df.median_income.hist(bins=50, figsize=(12,10))
plt.show()

# %%
sns.set(font_scale=1.5)
sns.jointplot(df['median_income'], df['median_house_value'], height=10, kind='reg')
plt.show()

# %%
sns.set(font_scale=1.5)
sns.jointplot(df['median_income'], df['median_house_value'], height=10, kind='kde')
plt.show()

# %%
df.plot(kind='scatter', x='longitude', y='latitude', cmap='coolwarm', c='median_house_value', s=df['population']/100, figsize=(15,10), alpha=0.4, sharex=False, label='Population', fontsize=14)
plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.legend(fontsize=16)
plt.show()

# %%
import matplotlib.image as mpimg
cali_img = mpimg.imread('california.png')

# %%
plt.figure(figsize=(15,10))
plt.imshow(cali_img)
plt.show()

# %%
#apply the scatter plot to the cali map image 

cali_img
# Out:
# array([[[0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667],
#         [0.9647059, 0.827451 , 0.6666667],
#         [0.9647059, 0.827451 , 0.6666667]],
#
#        [[0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667],
#         [0.9647059, 0.827451 , 0.6666667],
#         [0.9647059, 0.827451 , 0.6666667]],
#
#        [[0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667],
#         [0.9647059, 0.827451 , 0.6666667],
#         [0.9647059, 0.827451 , 0.6666667]],
#
#        ...,
#
#        [[0.627451 , 0.7764706, 0.9137255],
#         [0.627451 , 0.7764706, 0.9137255],
# ...

# %%
plt.figure(figsize=(15,10))
plt.imshow(cali_img, extent=[-124.55,-113.80, 32.45, 42.05])
plt.show()

# %%
df.plot(kind='scatter', x='longitude',y='latitude', s=df.population/100, label='Population', cmap='coolwarm', alpha=0.4, sharex=False, fontsize=14, colorbar=True, c='median_house_value', figsize=(15,10))
plt.imshow(cali_img, extent=[-124.55,-113.80, 32.45, 42.05], alpha=0.5, cmap=plt.get_cmap("jet"))
plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.legend(fontsize=16)
plt.show()

# %%
prox = df.ocean_proximity.unique()
prox
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df.loc[df['ocean_proximity']==prox[3]]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                16.0       2739.0           480.0
# 1851     -124.30     41.80                19.0       2672.0           552.0
# 1852     -124.23     41.75                11.0       3159.0           616.0
# 1853     -124.21     41.77                17.0       3461.0           722.0
# 1854     -124.19     41.78                15.0       3140.0           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                16.0       1316.0           194.0
# 20381    -118.83     34.14                16.0       1956.0           312.0
# 20423    -119.00     34.08                17.0       1822.0           438.0
# 20424    -118.75     34.18                 4.0      16704.0          2704.0
# 20425    -118.75     34.17                18.0       6217.0           858.0
#
# ...

# %%
df_loc = df.loc[df['ocean_proximity']==prox[3]]

# %%
df_loc.plot(kind='scatter', x='longitude',y='latitude', s=df_loc.population/100, label='Population', cmap='coolwarm', alpha=0.4, sharex=False, fontsize=14, colorbar=True, c='median_house_value', figsize=(15,10))
plt.imshow(cali_img, extent=[-124.55,-113.80, 32.45, 42.05], alpha=0.5, cmap=plt.get_cmap("jet"))
plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# Relationship between latitude (longitude) and house prices but no linear relationship
# - location matters
# - within non linear ML like random forest, can capture relationship between location and house prices

# %%
#income should be the most important feature 
#histogram with median income

df.median_income.hist(bins=50)
plt.show()

# %%
pd.qcut(df.median_income, [0, 0.25, 0.5, 0.75, 0.95, 1.0])
# Out:
# 0           (7.3, 15.0]
# 1           (7.3, 15.0]
# 2          (4.744, 7.3]
# 3          (4.744, 7.3]
# 4        (3.536, 4.744]
#               ...
# 20635    (0.499, 2.564]
# 20636    (0.499, 2.564]
# 20637    (0.499, 2.564]
# 20638    (0.499, 2.564]
# 20639    (0.499, 2.564]
# Name: median_income, Length: 20433, dtype: category
# Categories (5, interval[float64]): [(0.499, 2.564] < (2.564, 3.536] < (3.536, 4.744] < (4.744, 7.3] < (7.3, 15.0]]

# %%
df['income_cat'] = pd.qcut(df.median_income, q =[0, 0.25, 0.5, 0.75, 0.95, 1.0], 
                            labels = ['Low','Below Avg', 'Above Avg', 'High', 'Very High'])

# %%
df.income_cat
# Out:
# 0        Very High
# 1        Very High
# 2             High
# 3             High
# 4        Above Avg
#            ...
# 20635          Low
# 20636          Low
# 20637          Low
# 20638          Low
# 20639          Low
# Name: income_cat, Length: 20433, dtype: category
# Categories (5, object): ['Low' < 'Below Avg' < 'Above Avg' < 'High' < 'Very High']

# %%
df.income_cat.value_counts(normalize=True)
# Out:
# Above Avg    0.250037
# Low          0.250037
# Below Avg    0.249988
# High         0.199922
# Very High    0.050017
# Name: income_cat, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5, palette='viridis')
sns.countplot(data=df, x='income_cat', hue='ocean_proximity')
plt.legend(loc=1)
plt.show()

# %% [markdown]
# - Low income - mostly inland area
# - As income level goes up, # of people residing inland decreases
# - High income - mostly live <1H ocean

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=df['income_cat'], y=df['median_house_value'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=df['ocean_proximity'], y=df['median_house_value'])
plt.show()

# %% [markdown]
# inland clearly lower
# - island has only 5 hence could be ignored

# %%
df.groupby(['income_cat','ocean_proximity'])['median_house_value'].mean().unstack().drop(columns=['ISLAND'])
# Out:
# ocean_proximity      <1H OCEAN         INLAND       NEAR BAY     NEAR OCEAN
# income_cat
# Low              161337.076923   84820.626650  155122.052133  148027.826514
# Below Avg        197236.013829  115124.088283  220196.177656  208665.190096
# Above Avg        232278.358759  147846.891351  261965.251582  255293.813584
# High             292208.766217  208095.566622  322566.033663  337446.227778
# Very High        439784.235489  347571.736842  451015.078788  468739.723270

# %%
matrix = df.groupby(['income_cat','ocean_proximity'])['median_house_value'].mean().unstack().drop(columns=['ISLAND'])

# %%
matrix.astype('int')
# Out:
# ocean_proximity  <1H OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# income_cat
# Low                 161337   84820    155122      148027
# Below Avg           197236  115124    220196      208665
# Above Avg           232278  147846    261965      255293
# High                292208  208095    322566      337446
# Very High           439784  347571    451015      468739

# %%
plt.figure(figsize=(12,10))
sns.heatmap(matrix, annot=True, fmt='.2f', cmap='Blues')
plt.show()
